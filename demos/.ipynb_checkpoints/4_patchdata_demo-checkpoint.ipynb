# %% [markdown]
# # Demo for Patch data
# VR 2025-01-08

# %%
import retinanalysis as ra
import matplotlib.pyplot as plt
import numpy as np
# Out:
# [2026-02-09 14:57:04,332][INFO]: DataJoint 0.14.4 connected to root@127.0.0.1:3306

# %% [markdown]
# Parse h5 to json, then place h5 and json in database dirs, then populate database.

# %%
# ra.populate_database()

# %%
# I'm querying all patch experiments to find an example
ra.schema.Experiment() & 'is_mea=0'
# Out:
# *id     h5_uuid        exp_name       meta_file      data_file      tags_file      is_mea     date_added     label          properties attributes start_time     experimenter   institution    lab      project     rig      rig_type
# +-----+ +------------+ +------------+ +------------+ +------------+ +------------+ +--------+ +------------+ +------------+ +--------+ +--------+ +------------+ +------------+ +------------+ +------+ +---------+ +------+ +----------+
# 129     dca776e2-28bf- led_sawtooth_c /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-07-14 17: 20250210C      =BLOB=     =BLOB=     2025-02-10 17: None           None           None     None        None     PATCH
# 130     49cfe405-db8d- led_sine_calib /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-07-14 17: 20250207C      =BLOB=     =BLOB=     2025-02-07 15: None           None           None     None        None     PATCH
# 131     5ea348f5-c4f4- 2024-10-16_E   /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-07-14 17: Primate        =BLOB=     =BLOB=     2024-10-16 09: None           None           None     None        None     PATCH
# 132     2ea5fce8-6e53- 2025-04-29_E   /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-07-14 17: Primate        =BLOB=     =BLOB=     2025-04-29 11: None           None           None     None        None     PATCH
# 133     ea52da2b-4a18- crf_calibratio /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-07-14 17: Primate        =BLOB=     =BLOB=     2025-06-09 12: None           None           None     None        None     PATCH
# 134     41144cb0-d0e5- crf_calibratio /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-07-14 17: Primate        =BLOB=     =BLOB=     2025-06-15 16: None           None           None     None        None     PATCH
# 135     25b9ed03-55cc- crf_calibratio /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-07-14 17: Primate        =BLOB=     =BLOB=     2025-06-23 15: None           None           None     None        None     PATCH
# 139     cce71475-652d- 2025-08-11_dpa /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-08-12 16: Primate        =BLOB=     =BLOB=     2025-08-11 15: None           None           None     None        None     PATCH
# 149     e458a98f-04c6- frame_calibrat /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-08-21 15: Primate        =BLOB=     =BLOB=     2025-08-21 13: None           None           None     None        None     PATCH
# 173     40ded1a1-81b5- 20251121_noise /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-11-21 10: Primate        =BLOB=     =BLOB=     2025-11-21 10: None           None           None     None        None     PATCH
# 174     034fb76c-bc09- noise_test_092 /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2025-11-21 13: noise_test     =BLOB=     =BLOB=     2025-11-21 12: None           None           None     None        None     PATCH
# 185     67cdd3fc-5cf0- 2026-01-02_E_2 /Volumes/Vyom  /Volumes/Vyom  /Volumes/Vyom  0          2026-02-09 14: Primate        =BLOB=     =BLOB=     2026-01-02 16: None           None           None     None        None     PATCH
#  (Total: 12)

# %%
exp_name = '2025-04-29_E'
ra.get_exp_summary(exp_name)
# Out:
#         exp_name   prep_label recording_technique pipette_solution  cell_id  \
# 0   2025-04-29_E  Preparation                null             null      153
# 1   2025-04-29_E  Preparation                null             null      153
# 2   2025-04-29_E  Preparation                null             null      153
# 3   2025-04-29_E  Preparation                null             null      153
# 4   2025-04-29_E  Preparation                null             null      153
# 5   2025-04-29_E  Preparation                null             null      153
# 6   2025-04-29_E  Preparation                null             null      153
# 7   2025-04-29_E  Preparation                null             null      153
# 8   2025-04-29_E  Preparation                null             null      156
# 9   2025-04-29_E  Preparation                null             null      156
# 10  2025-04-29_E  Preparation                null             null      156
# 11  2025-04-29_E  Preparation                null             null      156
# 12  2025-04-29_E  Preparation                null             null      156
# 13  2025-04-29_E  Preparation                null             null      156
# 14  2025-04-29_E  Preparation                null             null      156
# 15  2025-04-29_E  Preparation                null             null      152
# 16  2025-04-29_E  Preparation                null             null      152
# 17  2025-04-29_E  Preparation                null             null      152
# 18  2025-04-29_E  Preparation                null             null      155
# 19  2025-04-29_E  Preparation                null             null      155
# 20  2025-04-29_E  Preparation                null             null      154
# 21  2025-04-29_E  Preparation                null             null      154
# 22  2025-04-29_E  Preparation                null             null      154
# 23  2025-04-29_E  Preparation                null             null      154
# 24  2025-04-29_E  Preparation                null             null      154
# 25  2025-04-29_E  Preparation                null             null      154
# 26  2025-04-29_E  Preparation                null             null      154
# 27  2025-04-29_E  Preparation                null             null      157
# 28  2025-04-29_E  Preparation                null             null      157
# 29  2025-04-29_E  Preparation                null             null      157
# 30  2025-04-29_E  Preparation                null             null      157
# 31  2025-04-29_E  Preparation                null             null      157
# 32  2025-04-29_E  Preparation                null             null      157
# 33  2025-04-29_E  Preparation                null             null      157
# 34  2025-04-29_E  Preparation                null             null      157
# 35  2025-04-29_E  Preparation                null             null      157
# 36  2025-04-29_E  Preparation                null             null      157
# 37  2025-04-29_E  Preparation                null             null      157
#
#    cell_label            cell_type  NDF  \
# 0       Cell1       RGC\ON-parasol  0.0
# 1       Cell1       RGC\ON-parasol  0.0
# 2       Cell1       RGC\ON-parasol  0.0
# 3       Cell1       RGC\ON-parasol  0.0
# 4       Cell1       RGC\ON-parasol  0.0
# 5       Cell1       RGC\ON-parasol  0.0
# 6       Cell1       RGC\ON-parasol  0.0
# 7       Cell1       RGC\ON-parasol  0.0
# 8       Cell2   bipolar\ON-diffuse  0.0
# 9       Cell2   bipolar\ON-diffuse  0.0
# 10      Cell2   bipolar\ON-diffuse  0.0
# 11      Cell2   bipolar\ON-diffuse  0.0
# 12      Cell2   bipolar\ON-diffuse  0.0
# 13      Cell2   bipolar\ON-diffuse  0.0
# 14      Cell2   bipolar\ON-diffuse  0.0
# 15      Cell3      RGC\OFF-parasol  0.0
# 16      Cell3      RGC\OFF-parasol  0.0
# 17      Cell3      RGC\OFF-parasol  0.0
# 18      Cell4        RGC\ON-midget  0.0
# 19      Cell4        RGC\ON-midget  0.0
# 20      Cell5       RGC\ON-parasol  1.0
# 21      Cell5       RGC\ON-parasol  1.0
# 22      Cell5       RGC\ON-parasol  1.0
# 23      Cell5       RGC\ON-parasol  1.0
# 24      Cell5       RGC\ON-parasol  1.0
# 25      Cell5       RGC\ON-parasol  1.0
# 26      Cell5       RGC\ON-parasol  1.0
# 27      Cell6  bipolar\OFF-diffuse  1.0
# 28      Cell6  bipolar\OFF-diffuse  1.0
# 29      Cell6  bipolar\OFF-diffuse  1.0
# 30      Cell6  bipolar\OFF-diffuse  1.0
# 31      Cell6  bipolar\OFF-diffuse  1.0
# 32      Cell6  bipolar\OFF-diffuse  1.0
# 33      Cell6  bipolar\OFF-diffuse  1.0
# 34      Cell6  bipolar\OFF-diffuse  1.0
# 35      Cell6  bipolar\OFF-diffuse  1.0
# 36      Cell6  bipolar\OFF-diffuse  1.0
# 37      Cell6  bipolar\OFF-diffuse  1.0
#
#                                         protocol_name  duration_minutes  \
# 0   edu.washington.riekelab.turner.protocols.Split...              0.08
# 1   edu.washington.riekelab.turner.protocols.Split...              0.07
# 2   edu.washington.riekelab.turner.protocols.Split...              0.18
# 3   edu.washington.riekelab.turner.protocols.Expan...              0.85
# 4   edu.washington.riekelab.turner.protocols.Contr...              1.18
# 5                 manookinlab.protocols.PresentImages             11.13
# 6   edu.washington.riekelab.rieke.protocols.Flashe...             13.88
# 7   edu.washington.riekelab.turner.protocols.Contr...              1.17
# 8        edu.washington.riekelab.protocols.SingleSpot              0.05
# 9   edu.washington.riekelab.turner.protocols.Split...              0.08
# 10  edu.washington.riekelab.turner.protocols.Split...              0.07
# 11  edu.washington.riekelab.turner.protocols.Split...              0.07
# 12  edu.washington.riekelab.turner.protocols.Expan...              0.23
# 13  edu.washington.riekelab.turner.protocols.Expan...              0.28
# 14  edu.washington.riekelab.turner.protocols.Doves...              2.35
# 15  edu.washington.riekelab.turner.protocols.Split...              0.07
# 16  edu.washington.riekelab.turner.protocols.Expan...              0.87
# 17                manookinlab.protocols.PresentImages             11.03
# 18  edu.washington.riekelab.turner.protocols.Expan...              0.87
# 19                manookinlab.protocols.PresentImages             11.17
# 20  edu.washington.riekelab.turner.protocols.Split...              0.07
# 21  edu.washington.riekelab.turner.protocols.Split...              0.20
# 22  edu.washington.riekelab.turner.protocols.Contr...              1.18
# 23  edu.washington.riekelab.turner.protocols.Contr...              1.18
# 24                manookinlab.protocols.PresentImages             11.02
# 25  edu.washington.riekelab.turner.protocols.Expan...              0.87
# 26                manookinlab.protocols.JitteredNoise              6.97
# 27       edu.washington.riekelab.protocols.SingleSpot              0.03
# 28  edu.washington.riekelab.turner.protocols.Split...              0.07
# 29  edu.washington.riekelab.turner.protocols.Split...              0.07
# 30  edu.washington.riekelab.turner.protocols.Split...              0.07
# 31  edu.washington.riekelab.turner.protocols.Split...              0.08
# 32  edu.washington.riekelab.turner.protocols.Split...              0.18
# 33  edu.washington.riekelab.turner.protocols.Split...              0.18
# 34  edu.washington.riekelab.turner.protocols.Split...              0.20
# 35  edu.washington.riekelab.turner.protocols.Expan...              0.03
# 36  edu.washington.riekelab.turner.protocols.Expan...              0.77
# 37  edu.washington.riekelab.turner.protocols.Doves...              5.32
#
#     minutes_since_start          start_time            end_time  \
# 0                  0.08 2025-04-29 12:04:06 2025-04-29 12:04:11
# 1                  0.23 2025-04-29 12:04:16 2025-04-29 12:04:20
# 2                  0.55 2025-04-29 12:04:28 2025-04-29 12:04:39
# 3                  2.15 2025-04-29 12:05:24 2025-04-29 12:06:15
# 4                  3.43 2025-04-29 12:06:21 2025-04-29 12:07:32
# 5                 15.13 2025-04-29 12:08:06 2025-04-29 12:19:14
# 6                 30.37 2025-04-29 12:20:35 2025-04-29 12:34:28
# 7                 32.03 2025-04-29 12:34:58 2025-04-29 12:36:08
# 8                 82.95 2025-04-29 13:27:00 2025-04-29 13:27:03
# 9                 83.23 2025-04-29 13:27:15 2025-04-29 13:27:20
# 10                83.55 2025-04-29 13:27:35 2025-04-29 13:27:39
# 11                83.68 2025-04-29 13:27:43 2025-04-29 13:27:47
# 12                84.08 2025-04-29 13:27:57 2025-04-29 13:28:11
# 13                84.45 2025-04-29 13:28:16 2025-04-29 13:28:33
# 14                87.28 2025-04-29 13:29:02 2025-04-29 13:31:23
# 15               155.30 2025-04-29 14:39:20 2025-04-29 14:39:24
# 16               156.28 2025-04-29 14:39:31 2025-04-29 14:40:23
# 17               167.72 2025-04-29 14:40:47 2025-04-29 14:51:49
# 18               175.13 2025-04-29 14:58:22 2025-04-29 14:59:14
# 19               186.45 2025-04-29 14:59:23 2025-04-29 15:10:33
# 20               198.15 2025-04-29 15:22:11 2025-04-29 15:22:15
# 21               198.48 2025-04-29 15:22:23 2025-04-29 15:22:35
# 22               200.05 2025-04-29 15:22:58 2025-04-29 15:24:09
# 23               201.42 2025-04-29 15:24:20 2025-04-29 15:25:31
# 24               212.87 2025-04-29 15:25:57 2025-04-29 15:36:58
# 25               214.38 2025-04-29 15:37:37 2025-04-29 15:38:29
# 26               221.57 2025-04-29 15:38:42 2025-04-29 15:45:40
# 27               243.18 2025-04-29 16:07:15 2025-04-29 16:07:17
# 28               243.33 2025-04-29 16:07:22 2025-04-29 16:07:26
# 29               244.28 2025-04-29 16:08:19 2025-04-29 16:08:23
# 30               244.45 2025-04-29 16:08:29 2025-04-29 16:08:33
# 31               244.90 2025-04-29 16:08:55 2025-04-29 16:09:00
# 32               245.17 2025-04-29 16:09:05 2025-04-29 16:09:16
# 33               245.42 2025-04-29 16:09:20 2025-04-29 16:09:31
# 34               245.67 2025-04-29 16:09:34 2025-04-29 16:09:46
# 35               245.78 2025-04-29 16:09:51 2025-04-29 16:09:53
# 36               246.63 2025-04-29 16:09:58 2025-04-29 16:10:44
# 37               252.17 2025-04-29 16:10:57 2025-04-29 16:16:16
#
#                     cell_properties group_label  experiment_id  prep_id  \
# 0        {'type': 'RGC\ON-parasol'}     Control            132      151
# 1        {'type': 'RGC\ON-parasol'}     Control            132      151
# 2        {'type': 'RGC\ON-parasol'}     Control            132      151
# 3        {'type': 'RGC\ON-parasol'}     Control            132      151
# 4        {'type': 'RGC\ON-parasol'}     Control            132      151
# 5        {'type': 'RGC\ON-parasol'}     Control            132      151
# 6        {'type': 'RGC\ON-parasol'}     Control            132      151
# 7        {'type': 'RGC\ON-parasol'}     Control            132      151
# 8    {'type': 'bipolar\ON-diffuse'}     Control            132      151
# 9    {'type': 'bipolar\ON-diffuse'}     Control            132      151
# 10   {'type': 'bipolar\ON-diffuse'}     Control            132      151
# 11   {'type': 'bipolar\ON-diffuse'}     Control            132      151
# 12   {'type': 'bipolar\ON-diffuse'}     Control            132      151
# 13   {'type': 'bipolar\ON-diffuse'}     Control            132      151
# 14   {'type': 'bipolar\ON-diffuse'}     Control            132      151
# 15      {'type': 'RGC\OFF-parasol'}     Control            132      151
# 16      {'type': 'RGC\OFF-parasol'}     Control            132      151
# 17      {'type': 'RGC\OFF-parasol'}     Control            132      151
# 18        {'type': 'RGC\ON-midget'}     Control            132      151
# 19        {'type': 'RGC\ON-midget'}     Control            132      151
# 20       {'type': 'RGC\ON-parasol'}     Control            132      151
# 21       {'type': 'RGC\ON-parasol'}     Control            132      151
# 22       {'type': 'RGC\ON-parasol'}     Control            132      151
# 23       {'type': 'RGC\ON-parasol'}     Control            132      151
# 24       {'type': 'RGC\ON-parasol'}     Control            132      151
# 25       {'type': 'RGC\ON-parasol'}     Control            132      151
# 26       {'type': 'RGC\ON-parasol'}     Control            132      151
# 27  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 28  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 29  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 30  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 31  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 32  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 33  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 34  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 35  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 36  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
# 37  {'type': 'bipolar\OFF-diffuse'}     Control            132      151
#
#     group_id  block_id  protocol_id
# 0       2318      3379           73
# 1       2318      3380           73
# 2       2318      3381           73
# 3       2318      3382           71
# 4       2318      3383           75
# 5       2318      3384           16
# 6       2318      3385           76
# 7       2318      3386           75
# 8       2321      3396            2
# 9       2321      3397           73
# 10      2321      3398           73
# 11      2321      3399           73
# 12      2321      3400           71
# 13      2321      3401           71
# 14      2321      3402           74
# 15      2317      3376           73
# 16      2317      3377           71
# 17      2317      3378           16
# 18      2320      3394           71
# 19      2320      3395           16
# 20      2319      3387           73
# 21      2319      3388           73
# 22      2319      3389           75
# 23      2319      3390           75
# 24      2319      3391           16
# 25      2319      3392           71
# 26      2319      3393           77
# 27      2322      3403            2
# 28      2322      3404           73
# 29      2322      3405           73
# 30      2322      3406           73
# 31      2322      3407           73
# 32      2322      3408           73
# 33      2322      3409           73
# 34      2322      3410           73
# 35      2322      3411           71
# 36      2322      3412           71
# 37      2322      3413           74

# %% [markdown]
# For Cell1 ON-Parasol let's get the expanding spots data

# %%
df_exp = ra.get_exp_summary(exp_name)
cell_label = 'Cell1'
df_exp.query('cell_label == @cell_label')
# Out:
#        exp_name   prep_label recording_technique pipette_solution  cell_id  \
# 0  2025-04-29_E  Preparation                null             null      153
# 1  2025-04-29_E  Preparation                null             null      153
# 2  2025-04-29_E  Preparation                null             null      153
# 3  2025-04-29_E  Preparation                null             null      153
# 4  2025-04-29_E  Preparation                null             null      153
# 5  2025-04-29_E  Preparation                null             null      153
# 6  2025-04-29_E  Preparation                null             null      153
# 7  2025-04-29_E  Preparation                null             null      153
#
#   cell_label       cell_type  NDF  \
# 0      Cell1  RGC\ON-parasol  0.0
# 1      Cell1  RGC\ON-parasol  0.0
# 2      Cell1  RGC\ON-parasol  0.0
# 3      Cell1  RGC\ON-parasol  0.0
# 4      Cell1  RGC\ON-parasol  0.0
# 5      Cell1  RGC\ON-parasol  0.0
# 6      Cell1  RGC\ON-parasol  0.0
# 7      Cell1  RGC\ON-parasol  0.0
#
#                                        protocol_name  duration_minutes  \
# 0  edu.washington.riekelab.turner.protocols.Split...              0.08
# 1  edu.washington.riekelab.turner.protocols.Split...              0.07
# 2  edu.washington.riekelab.turner.protocols.Split...              0.18
# 3  edu.washington.riekelab.turner.protocols.Expan...              0.85
# 4  edu.washington.riekelab.turner.protocols.Contr...              1.18
# 5                manookinlab.protocols.PresentImages             11.13
# 6  edu.washington.riekelab.rieke.protocols.Flashe...             13.88
# 7  edu.washington.riekelab.turner.protocols.Contr...              1.17
#
#    minutes_since_start          start_time            end_time  \
# 0                 0.08 2025-04-29 12:04:06 2025-04-29 12:04:11
# 1                 0.23 2025-04-29 12:04:16 2025-04-29 12:04:20
# 2                 0.55 2025-04-29 12:04:28 2025-04-29 12:04:39
# 3                 2.15 2025-04-29 12:05:24 2025-04-29 12:06:15
# 4                 3.43 2025-04-29 12:06:21 2025-04-29 12:07:32
# 5                15.13 2025-04-29 12:08:06 2025-04-29 12:19:14
# 6                30.37 2025-04-29 12:20:35 2025-04-29 12:34:28
# 7                32.03 2025-04-29 12:34:58 2025-04-29 12:36:08
#
#               cell_properties group_label  experiment_id  prep_id  group_id  \
# 0  {'type': 'RGC\ON-parasol'}     Control            132      151      2318
# 1  {'type': 'RGC\ON-parasol'}     Control            132      151      2318
# 2  {'type': 'RGC\ON-parasol'}     Control            132      151      2318
# 3  {'type': 'RGC\ON-parasol'}     Control            132      151      2318
# 4  {'type': 'RGC\ON-parasol'}     Control            132      151      2318
# 5  {'type': 'RGC\ON-parasol'}     Control            132      151      2318
# 6  {'type': 'RGC\ON-parasol'}     Control            132      151      2318
# 7  {'type': 'RGC\ON-parasol'}     Control            132      151      2318
#
#    block_id  protocol_id
# 0      3379           73
# 1      3380           73
# 2      3381           73
# 3      3382           71
# 4      3383           75
# 5      3384           16
# 6      3385           76
# 7      3386           75

# %%
# Block ID from table above, or can query by protocol name etc.
block_id = 3382
sb = ra.StimBlock(exp_name, block_id)

# Note we're using SCResponseBlock. b_spiking=True will run spike detection.
rb = ra.SCResponseBlock(exp_name, block_id, b_spiking=True)
# Out:
# Initializing StimBlock for 2025-04-29_E block 3382
# Initializing ResponseBlock for 2025-04-29_E block 3382
# Warning: for 2025-04-29_E block 3382, error in finding stage frame rate.
# Error occurred while getting actual onset/offset times: unsupported operand type(s) for *: 'float' and 'NoneType'
# It could be that frame_times_ms do not have the correct number of frames due to some error in frame detection.
# Check the frame monitor sample rate! On MEA Rigs, prefer 1k, errors likely with 10k.
# Loading frame monitor data from /Volumes/Vyom MEA/data/samarjit_datajoint/data_dirs/data/2025-04-29_E.h5 ...
# Loaded (33, 7500) frame_data.
#
# Loading Amp1 data from /Volumes/Vyom MEA/data/samarjit_datajoint/data_dirs/data/2025-04-29_E.h5 ...
# Loaded (33, 7500) amp_data.
#
# Max trial length in data points: 10000 = 1 s
# Trial 1: Found 1555 peaks
# Trial 1: Found 22 spikes
# Trial 2: Found 1546 peaks
# Trial 2: Found 25 spikes
# Trial 3: Found 1522 peaks
# Trial 3: Found 28 spikes
# Trial 4: Found 1518 peaks
# Trial 4: Found 29 spikes
# Trial 5: Found 1508 peaks
# Trial 5: Found 30 spikes
# Trial 6: Found 1520 peaks
# Trial 6: Found 28 spikes
# Trial 7: Found 1507 peaks
# Trial 7: Found 27 spikes
# Trial 8: Found 1575 peaks
# Trial 8: Found 22 spikes
# Trial 9: Found 1557 peaks
# Trial 9: Found 22 spikes
# Trial 10: Found 1519 peaks
# Trial 10: Found 28 spikes
# Trial 11: Found 1500 peaks
# Trial 11: Found 27 spikes
# Trial 12: Found 1523 peaks
# Trial 12: Found 22 spikes
# Trial 13: Found 1551 peaks
# Trial 13: Found 18 spikes
# Trial 14: Found 1561 peaks
# Trial 14: Found 21 spikes
# Trial 15: Found 1506 peaks
# Trial 15: Found 26 spikes
# Trial 16: Found 1517 peaks
# Trial 16: Found 34 spikes
# Trial 17: Found 1509 peaks
# Trial 17: Found 30 spikes
# Trial 18: Found 1493 peaks
# Trial 18: Found 35 spikes
# Trial 19: Found 1528 peaks
# Trial 19: Found 27 spikes
# Trial 20: Found 1557 peaks
# Trial 20: Found 22 spikes
# Trial 21: Found 1552 peaks
# Trial 21: Found 25 spikes
# Trial 22: Found 1547 peaks
# Trial 22: Found 24 spikes
# Trial 23: Found 1562 peaks
# Trial 23: Found 20 spikes
# Trial 24: Found 1548 peaks
# Trial 24: Found 24 spikes
# Trial 25: Found 1486 peaks
# Trial 25: Found 27 spikes
# Trial 26: Found 1500 peaks
# Trial 26: Found 34 spikes
# Trial 27: Found 1515 peaks
# Trial 27: Found 35 spikes
# Trial 28: Found 1514 peaks
# Trial 28: Found 37 spikes
# Trial 29: Found 1504 peaks
# Trial 29: Found 31 spikes
# Trial 30: Found 1514 peaks
# Trial 30: Found 25 spikes
# Trial 31: Found 1528 peaks
# Trial 31: Found 28 spikes
# Trial 32: Found 1544 peaks
# Trial 32: Found 25 spikes
# Trial 33: Found 1552 peaks
# Trial 33: Found 25 spikes

# %% [markdown]
# ## Plot example trace and summary spikes

# %%
sb.df_epochs.head()
# Out:
#    epoch_index  currentSpotSize      exp_name group_label  \
# 0            0             25.0  2025-04-29_E     Control
# 1            1             50.0  2025-04-29_E     Control
# 2            2            100.0  2025-04-29_E     Control
# 3            3            150.0  2025-04-29_E     Control
# 4            4            200.0  2025-04-29_E     Control
#
#                                        protocol_name  \
# 0  edu.washington.riekelab.turner.protocols.Expan...
# 1  edu.washington.riekelab.turner.protocols.Expan...
# 2  edu.washington.riekelab.turner.protocols.Expan...
# 3  edu.washington.riekelab.turner.protocols.Expan...
# 4  edu.washington.riekelab.turner.protocols.Expan...
#
#                                       frame_times_ms  \
# 0  [0.0, 17.0, 34.0, 50.0, 67.0, 84.0, 100.0, 117...
# 1  [0.0, 17.0, 34.0, 50.0, 67.0, 84.0, 100.0, 117...
# 2  [0.0, 17.0, 34.0, 50.0, 67.0, 84.0, 100.0, 117...
# 3  [0.0, 17.0, 34.0, 50.0, 67.0, 84.0, 100.0, 117...
# 4  [0.0, 17.0, 34.0, 50.0, 67.0, 84.0, 100.0, 117...
#
#                                     epoch_parameters  preTime  stimTime  \
# 0  {'NDF': 0.0, 'amp': 'Amp1', 'gain': None, 'ndf...    250.0     250.0
# 1  {'NDF': 0.0, 'amp': 'Amp1', 'gain': None, 'ndf...    250.0     250.0
# 2  {'NDF': 0.0, 'amp': 'Amp1', 'gain': None, 'ndf...    250.0     250.0
# 3  {'NDF': 0.0, 'amp': 'Amp1', 'gain': None, 'ndf...    250.0     250.0
# 4  {'NDF': 0.0, 'amp': 'Amp1', 'gain': None, 'ndf...    250.0     250.0
#
#    tailTime  experiment_id  group_id  block_id  protocol_id  epoch_id
# 0     250.0            132      2318      3382           71    243882
# 1     250.0            132      2318      3382           71    243883
# 2     250.0            132      2318      3382           71    243884
# 3     250.0            132      2318      3382           71    243885
# 4     250.0            132      2318      3382           71    243886

# %%
spot_sizes = sb.df_epochs['currentSpotSize'].values

# %%
# Example trace from 3rd epoch
def plot_eg_trace(rb, sb, i_epoch):
    f, ax = plt.subplots(1, 1, figsize=(10, 5))
    raw = rb.amp_data[i_epoch]
    sts = rb.spike_times[i_epoch]
    time = np.arange(len(raw)) / rb.amp_sample_rate
    ax.plot(time, raw, label='Raw trace')
    ax.scatter(sts/rb.amp_sample_rate, raw[sts], color='r')
    pre_time = sb.df_epochs.at[i_epoch, 'preTime']
    # Hacky correction for first missing frame. Need to implement frame monitor based timing.
    pre_time -= 1/60 * 1000
    stim_time = sb.df_epochs.at[i_epoch, 'stimTime']
    offset_time = pre_time + stim_time
    ax.axvline(pre_time / 1000, c='k', label='Stim onset')
    ax.axvline(offset_time / 1000, c='grey', label='Stim offset')
    spot_size = sb.df_epochs.at[i_epoch, 'currentSpotSize']
    ax.set_title(f'Epoch index {i_epoch}\n{spot_size}um spot')
    ax.set_xlabel('Time (s)')
    ax.set_ylabel('Amplitude')
    ax.legend()

i_epoch = 2
plot_eg_trace(rb, sb, i_epoch)

# %%
def get_stim_nspikes(sb, rb, b_sub_baseline: bool=False):
    ls_nsps = []
    for e_idx in sb.df_epochs.index:
        pre_time = sb.df_epochs.at[e_idx, 'preTime']
        
        # Hacky correction for first missing frame. Need to implement frame monitor based timing.
        pre_time -= 1/60 * 1000
        stim_time = sb.df_epochs.at[e_idx, 'stimTime']
        offset_time = pre_time + stim_time
        # Convert from ms to samples
        onset_samples = int(np.round(pre_time * rb.amp_sample_rate / 1000))
        offset_samples = int(np.round(offset_time * rb.amp_sample_rate / 1000))
        sts = rb.spike_times[e_idx]
        n_sps = len(sts[(sts >= onset_samples) & (sts <= offset_samples)])
        if b_sub_baseline:
            n_baseline = len(sts[(sts < onset_samples)])
            n_sps -= n_baseline
        ls_nsps.append(n_sps)
    stim_spikes = np.array(ls_nsps)

    return stim_spikes

stim_spikes = get_stim_nspikes(sb, rb, b_sub_baseline=False)

# %%
plt.scatter(spot_sizes, stim_spikes, c='k')
plt.xlabel('Spot size (um)')
plt.ylabel('Number of spikes during spot flash period')
# Out:
# Text(0, 0.5, 'Number of spikes during spot flash period')
